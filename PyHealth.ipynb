# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pprint import pprint

# %%
cdc_df = pd.read_csv("CDC.csv")
cdc_df.head()
# Out:
#                                              Disease  MMWR year  MMWR week  \
# 0                                            Anthrax     2018.0        1.0
# 1  Arboviral diseases, neuroinvasive and  nonneur...     2018.0        1.0
# 2  Arboviral diseases, neuroinvasive and  nonneur...     2018.0        1.0
# 3  Arboviral diseases, neuroinvasive and  nonneur...     2018.0        1.0
# 4  Arboviral diseases, neuroinvasive and  nonneur...     2018.0        1.0
#
#    Current week Current week, flag Cum 2018 Cum 2018, flag  \
# 0           NaN                  -      NaN              -
# 1           NaN                  -      NaN              -
# 2           NaN                  -      NaN              -
# 3           NaN                  -      NaN              -
# 4           NaN                  -      NaN              -
#
#    5-year weekly average 5-year weekly average§, flag  \
# 0                    NaN                            -
# 1                    6.0                          NaN
# 2                    0.0                          NaN
# 3                    0.0                          NaN
# 4                    NaN                            -
#
#   Total cases reported for pervious years  2017  \
# 0                                           NaN
# 1                                           115
# 2                                             3
# 3                                            67
# 4                                            44
#
#   Total cases reported for pervious years 2017, flag  \
# 0                                                  -
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total cases reported for pervious years 2016  \
# 0                                           NaN
# 1                                         247.0
# 2                                           7.0
# 3                                          15.0
# 4                                          35.0
#
#   Total cases reported for pervious years 2016, flag  \
# 0                                                  -
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total cases reported for pervious years 2015  \
# 0                                           NaN
# 1                                         896.0
# 2                                           6.0
# 3                                          11.0
# 4                                          55.0
#
#   Total cases reported for pervious years 2015, flag  \
# 0                                                  -
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total cases reported for pervious years 2014  \
# 0                                           NaN
# 1                                           NaN
# 2                                           8.0
# 3                                          11.0
# 4                                          80.0
#
#   Total cases reported for pervious years 2014, flag  \
# 0                                                  -
# 1                                                 NN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total cases reported for pervious years 2013  \
# 0                                           NaN
# 1                                           NaN
# 2                                           8.0
# 3                                          22.0
# 4                                          85.0
#
#   Total cases reported for pervious years 2013, flag  \
# 0                                                  -
# 1                                                 NN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   States reporting cases during current week (No.)
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN

# %%
cdc_short = cdc_df.drop(['Current week','Current week, flag', 
                         'Cum 2018','Cum 2018, flag', 
                         'MMWR year',
                         'MMWR week',
            'Total cases reported for pervious years 2017, flag',
             'Total cases reported for pervious years 2016, flag',
             'Total cases reported for pervious years 2015, flag',
            'Total cases reported for pervious years 2014, flag',
            'Total cases reported for pervious years 2013, flag'], axis=1)
cdc_short.head()
# Out:
#                                              Disease  5-year weekly average  \
# 0                                            Anthrax                    NaN
# 1  Arboviral diseases, neuroinvasive and  nonneur...                    6.0
# 2  Arboviral diseases, neuroinvasive and  nonneur...                    0.0
# 3  Arboviral diseases, neuroinvasive and  nonneur...                    0.0
# 4  Arboviral diseases, neuroinvasive and  nonneur...                    NaN
#
#   5-year weekly average§, flag Total cases reported for pervious years  2017  \
# 0                            -                                           NaN
# 1                          NaN                                           115
# 2                          NaN                                             3
# 3                          NaN                                            67
# 4                            -                                            44
#
#    Total cases reported for pervious years 2016  \
# 0                                           NaN
# 1                                         247.0
# 2                                           7.0
# 3                                          15.0
# 4                                          35.0
#
#    Total cases reported for pervious years 2015  \
# 0                                           NaN
# 1                                         896.0
# 2                                           6.0
# 3                                          11.0
# 4                                          55.0
#
#    Total cases reported for pervious years 2014  \
# 0                                           NaN
# 1                                           NaN
# 2                                           8.0
# 3                                          11.0
# 4                                          80.0
#
#    Total cases reported for pervious years 2013  \
# 0                                           NaN
# 1                                           NaN
# 2                                           8.0
# 3                                          22.0
# 4                                          85.0
#
#   States reporting cases during current week (No.)
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN

# %%
cdc_shorter = cdc_short.drop(cdc_short.columns[[1,2,8]], axis=1)
cdc_shorter.head()
# Out:
#                                              Disease  \
# 0                                            Anthrax
# 1  Arboviral diseases, neuroinvasive and  nonneur...
# 2  Arboviral diseases, neuroinvasive and  nonneur...
# 3  Arboviral diseases, neuroinvasive and  nonneur...
# 4  Arboviral diseases, neuroinvasive and  nonneur...
#
#   Total cases reported for pervious years  2017  \
# 0                                           NaN
# 1                                           115
# 2                                             3
# 3                                            67
# 4                                            44
#
#    Total cases reported for pervious years 2016  \
# 0                                           NaN
# 1                                         247.0
# 2                                           7.0
# 3                                          15.0
# 4                                          35.0
#
#    Total cases reported for pervious years 2015  \
# 0                                           NaN
# 1                                         896.0
# 2                                           6.0
# 3                                          11.0
# 4                                          55.0
#
#    Total cases reported for pervious years 2014  \
# 0                                           NaN
# 1                                           NaN
# 2                                           8.0
# 3                                          11.0
# 4                                          80.0
#
#    Total cases reported for pervious years 2013
# 0                                           NaN
# 1                                           NaN
# 2                                           8.0
# 3                                          22.0
# 4                                          85.0

# %%
cdc_shorter = cdc_shorter.rename(index=str, columns={"Total cases reported for pervious years  2017": "2017", 
                                           "Total cases reported for pervious years 2016": "2016",
                                           "Total cases reported for pervious years 2015": "2015",
                                           "Total cases reported for pervious years 2014": "2014",
                                           "Total cases reported for pervious years 2013": "2013"
                                          }
)

# %%
cdc_shorter.head()
# Out:
#                                              Disease 2017   2016   2015  2014  \
# 0                                            Anthrax  NaN    NaN    NaN   NaN
# 1  Arboviral diseases, neuroinvasive and  nonneur...  115  247.0  896.0   NaN
# 2  Arboviral diseases, neuroinvasive and  nonneur...    3    7.0    6.0   8.0
# 3  Arboviral diseases, neuroinvasive and  nonneur...   67   15.0   11.0  11.0
# 4  Arboviral diseases, neuroinvasive and  nonneur...   44   35.0   55.0  80.0
#
#    2013
# 0   NaN
# 1   NaN
# 2   8.0
# 3  22.0
# 4  85.0

# %%
column_order = cdc_shorter.columns.tolist()
column_order = column_order[::-1]
cdc_shorter = cdc_shorter[column_order]

# %%
cdc_shorter.head()
# Out:
#    2013  2014   2015   2016 2017  \
# 0   NaN   NaN    NaN    NaN  NaN
# 1   NaN   NaN  896.0  247.0  115
# 2   8.0   8.0    6.0    7.0    3
# 3  22.0  11.0   11.0   15.0   67
# 4  85.0  80.0   55.0   35.0   44
#
#                                              Disease
# 0                                            Anthrax
# 1  Arboviral diseases, neuroinvasive and  nonneur...
# 2  Arboviral diseases, neuroinvasive and  nonneur...
# 3  Arboviral diseases, neuroinvasive and  nonneur...
# 4  Arboviral diseases, neuroinvasive and  nonneur...

# %%
cdc_shorter_two = cdc_shorter.drop(cdc_shorter.index[0:29])

# %%
cdc_shorter_two.head()
# Out:
#      2013   2014   2015   2016 2017                                   Disease
# 29  187.0  667.0  188.0   85.0  122                                   Measles
# 30  142.0  123.0  120.0  126.0   66    Meningococcal disease, Serogroups ACWY
# 31   99.0   89.0  111.0   86.0   67        Meningococcal disease, Serogroup B
# 32   17.0   25.0   21.0   21.0   14   Meningococcal disease, Other serogroups
# 33  298.0  196.0  120.0  142.0  187  Meningococcal disease, Unknown serogroup

# %%
cdc_shorter_three = cdc_shorter_two.drop(cdc_shorter.index[30:3393])

# %%
cdc_shorter_three
# Out:
#      2013   2014   2015  2016 2017  Disease
# 29  187.0  667.0  188.0  85.0  122  Measles

# %%
cdc_shorter_three = cdc_shorter_three.reset_index(drop=True)
cdc_shorter_three
# Out:
#     2013   2014   2015  2016 2017  Disease
# 0  187.0  667.0  188.0  85.0  122  Measles

# %%
#Setting column headers as x-axis   
#plt.style.use('ggplot')
#ax = df[['Men','Women']].plot(kind='bar', title ="Population",figsize=(15,10),legend=True, fontsize=12)
#ax.set_xlabel("Areas",fontsize=12)
#ax.set_ylabel("Population",fontsize=12)
#plt.show()

# %%
#cdc_df2 = cdc_shorter.iloc[29]

# %%
#cdc_df2.head()

# %%
#measles

# %%
#measles_df = pd.DataFrame(measles)

# %%
#measles_df

# %%
#measles_df.head()

# %%
#column_order = measles_df.columns.tolist()
#column_order = column_order[::-1]
#measles_df = measles_df[column_order]

# %%
#measles_df

# %%
#measles_df2 = measles_df.transpose()

# %%
cdc_shorter.head()
# Out:
#    2013  2014   2015   2016 2017  \
# 0   NaN   NaN    NaN    NaN  NaN
# 1   NaN   NaN  896.0  247.0  115
# 2   8.0   8.0    6.0    7.0    3
# 3  22.0  11.0   11.0   15.0   67
# 4  85.0  80.0   55.0   35.0   44
#
#                                              Disease
# 0                                            Anthrax
# 1  Arboviral diseases, neuroinvasive and  nonneur...
# 2  Arboviral diseases, neuroinvasive and  nonneur...
# 3  Arboviral diseases, neuroinvasive and  nonneur...
# 4  Arboviral diseases, neuroinvasive and  nonneur...

# %%
#years = list(cdc_shorter.columns.values)

# %%
#list(cdc_shorter)

# %%
#years

# %%
NNDSS_df = pd.read_csv("NNDSS_-_TABLE_1V._Malaria_to_Measles__Imported-10.csv")
NNDSS_df.head()
# Out:
#        Reporting Area  MMWR Year  MMWR Week  Malaria, Current week  \
# 0              ALASKA       2019          1                    NaN
# 1        PENNSYLVANIA       2019          1                    NaN
# 2  WEST SOUTH CENTRAL       2019          1                    NaN
# 3             INDIANA       2019          1                    NaN
# 4      AMERICAN SAMOA       2019          1                    NaN
#
#   Malaria, Current week, flag  Malaria, Previous 52 weeks Max   \
# 0                           -                              1.0
# 1                           -                              8.0
# 2                           -                              5.0
# 3                           -                              1.0
# 4                           -                              0.0
#
#   Malaria, Previous 52 weeks Max, flag  Malaria, Cum 2019   \
# 0                                  NaN                 NaN
# 1                                  NaN                 NaN
# 2                                  NaN                 NaN
# 3                                  NaN                 NaN
# 4                                  NaN                 NaN
#
#   Malaria, Cum 2019, flag  Malaria, Cum 2018   ...  \
# 0                       -                 NaN  ...
# 1                       -                 NaN  ...
# 2                       -                 NaN  ...
# 3                       -                 1.0  ...
# 4                       -                 NaN  ...
#
#   Measles Imported Current week flag  Measles Imported Previous 52 weeks Max   \
# 0                                  -                                      0.0
# 1                                  -                                      1.0
# 2                                  -                                      1.0
# 3                                  -                                      1.0
# 4                                  -                                      0.0
#
#   Measles Imported Previous 52 weeks Max flag  Measles Imported Cum 2019   \
# 0                                         NaN                         NaN
# 1                                         NaN                         NaN
# 2                                         NaN                         NaN
# 3                                         NaN                         NaN
# 4                                         NaN                         NaN
#
#   Measles Imported Cum 2019 flag  Measles Imported Cum 2018   \
# 0                              -                         NaN
# 1                              -                         NaN
# 2                              -                         NaN
# 3                              -                         1.0
# 4                              -                         NaN
#
#   Measles Imported Cum 2018 flag                             Location 1  \
# 0                              -       ALASKA\n(63.631126, -151.631889)
# 1                              -  PENNSYLVANIA\n(40.896694, -77.838886)
# 2                              -                                    NaN
# 3                            NaN         INDIANA\n(39.919991, -86.2818)
# 4                              -                                    NaN
#
#            Location 2  Reporting Area Sort
# 0                 NaN             20190158
# 1                 NaN             20190113
# 2  WEST SOUTH CENTRAL             20190143
# 3                 NaN             20190116
# 4      AMERICAN SAMOA             20190164
#
# [5 rows x 30 columns]

# %%
NNDSS_df2 = NNDSS_df.drop(NNDSS_df.columns[[1,3,4,5,6,7,8,9,10,12,14,16,18,20,22,24,26,27,28,29]], axis=1)
NNDSS_df2
# Out:
#                 Reporting Area  MMWR Week  Measles Indigenous Current week  \
# 0                       ALASKA          1                              NaN
# 1                 PENNSYLVANIA          1                              NaN
# 2           WEST SOUTH CENTRAL          1                              NaN
# 3                      INDIANA          1                              NaN
# 4               AMERICAN SAMOA          1                              NaN
# 5                        TOTAL          1                              NaN
# 6                      VERMONT          1                              NaN
# 7                 SOUTH DAKOTA          1                              NaN
# 8           WEST NORTH CENTRAL          1                              NaN
# 9                     OKLAHOMA          1                              NaN
# 10                    COLORADO          1                              NaN
# 11                      HAWAII          1                              NaN
# 12              NORTH CAROLINA          1                              NaN
# 13                    ILLINOIS          1                              NaN
# 14               NEW YORK CITY          1                              NaN
# 15                  WASHINGTON          1                              NaN
# 16                   MINNESOTA          1                              NaN
# 17          EAST NORTH CENTRAL          1                              NaN
# 18                  NEW MEXICO          1                              NaN
# 19                      KANSAS          1                              NaN
# 20              SOUTH ATLANTIC          1                              NaN
# 21          EAST SOUTH CENTRAL          1                              NaN
# 22                     FLORIDA          1                              NaN
# 23                       TEXAS          1                              NaN
# 24                       IDAHO          1                              NaN
# 25                     WYOMING          1                              NaN
# 26               NEW HAMPSHIRE          1                              NaN
# 27                    MARYLAND          1                              NaN
# 28                 CONNECTICUT          1                              NaN
# 29                 MISSISSIPPI          1                              NaN
# ...                        ...        ...                              ...
# 1790                  KENTUCKY         26                              NaN
# 1791               MISSISSIPPI         26                              NaN
# 1792                 TENNESSEE         26                              NaN
# 1793        WEST SOUTH CENTRAL         26                              NaN
# 1794                  ARKANSAS         26                              NaN
# 1795                 LOUISIANA         26                              NaN
# 1796                  OKLAHOMA         26                              NaN
# 1797                     TEXAS         26                              NaN
# 1798                  MOUNTAIN         26                              NaN
# 1799                   ARIZONA         26                              NaN
# 1800                  COLORADO         26                              NaN
# 1801                     IDAHO         26                              NaN
# 1802                   MONTANA         26                              NaN
# 1803                    NEVADA         26                              NaN
# 1804                NEW MEXICO         26                              NaN
# 1805                      UTAH         26                              NaN
# 1806                   WYOMING         26                              NaN
# 1807                   PACIFIC         26                              NaN
# 1808                    ALASKA         26                              NaN
# 1809                CALIFORNIA         26                              NaN
# 1810                    HAWAII         26                              NaN
# 1811                WASHINGTON         26                              NaN
# 1812            US TERRITORIES         26                              NaN
# 1813            AMERICAN SAMOA         26                              NaN
# 1814  NORTHERN MARIANA ISLANDS         26                              NaN
# 1815                      GUAM         26                              NaN
# 1816               PUERTO RICO         26                              NaN
# 1817       U.S. VIRGIN ISLANDS         26                              NaN
# 1818          NON-US RESIDENTS         26                              NaN
# 1819                     TOTAL         26                              NaN
#
#       Measles Indigenous Previous 52 weeks Max   Measles Indigenous Cum 2019   \
# 0                                           0.0                           NaN
# 1                                           0.0                           NaN
# 2                                           5.0                           NaN
# 3                                           0.0                           NaN
# 4                                           0.0                           NaN
# 5                                           9.0                           NaN
# 6                                           0.0                           NaN
# 7                                           0.0                           NaN
# 8                                           5.0                           NaN
# 9                                           0.0                           NaN
# 10                                          0.0                           NaN
# 11                                          0.0                           NaN
# 12                                          1.0                           NaN
# 13                                          1.0                           NaN
# 14                                          9.0                           NaN
# 15                                          0.0                           NaN
# 16                                          0.0                           NaN
# 17                                          1.0                           NaN
# 18                                          0.0                           NaN
# 19                                          5.0                           NaN
# 20                                          3.0                           NaN
# 21                                          0.0                           NaN
# 22                                          3.0                           NaN
# 23                                          5.0                           NaN
# 24                                          0.0                           NaN
# 25                                          0.0                           NaN
# 26                                          0.0                           NaN
# 27                                          0.0                           NaN
# 28                                          0.0                           NaN
# 29                                          0.0                           NaN
# ...                                         ...                           ...
# 1790                                        1.0                           1.0
# 1791                                        0.0                           NaN
# 1792                                        2.0                           4.0
# 1793                                        5.0                          13.0
# 1794                                        0.0                           NaN
# 1795                                        0.0                           NaN
# 1796                                        2.0                           3.0
# 1797                                        5.0                          10.0
# 1798                                        1.0                           1.0
# 1799                                        0.0                           NaN
# 1800                                        0.0                           NaN
# 1801                                        0.0                           NaN
# 1802                                        0.0                           NaN
# 1803                                        0.0                           NaN
# 1804                                        1.0                           1.0
# 1805                                        0.0                           NaN
# 1806                                        0.0                           NaN
# 1807                                       17.0                         115.0
# 1808                                        0.0                           NaN
# 1809                                        9.0                          28.0
# 1810                                        0.0                           NaN
# 1811                                       17.0                          76.0
# 1812                                        0.0                           NaN
# 1813                                        0.0                           NaN
# 1814                                        0.0                           NaN
# 1815                                        0.0                           NaN
# 1816                                        0.0                           NaN
# 1817                                        0.0                           NaN
# 1818                                        NaN                           NaN
# 1819                                       60.0                         668.0
#
#       Measles Indigenous Cum 2018   Measles Imported Current week  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# 5                              NaN                            NaN
# 6                              NaN                            NaN
# 7                              NaN                            NaN
# 8                              NaN                            NaN
# 9                              NaN                            NaN
# 10                             NaN                            NaN
# 11                             NaN                            NaN
# 12                             NaN                            NaN
# 13                             NaN                            NaN
# 14                             NaN                            NaN
# 15                             NaN                            NaN
# 16                             NaN                            NaN
# 17                             NaN                            NaN
# 18                             NaN                            NaN
# 19                             NaN                            NaN
# 20                             NaN                            NaN
# 21                             NaN                            NaN
# 22                             NaN                            NaN
# 23                             NaN                            NaN
# 24                             NaN                            NaN
# 25                             NaN                            NaN
# 26                             NaN                            NaN
# 27                             NaN                            NaN
# 28                             NaN                            NaN
# 29                             NaN                            NaN
# ...                            ...                            ...
# 1790                           NaN                            NaN
# 1791                           NaN                            NaN
# 1792                           NaN                            NaN
# 1793                           5.0                            NaN
# 1794                           NaN                            NaN
# 1795                           NaN                            NaN
# 1796                           NaN                            NaN
# 1797                           5.0                            NaN
# 1798                           NaN                            NaN
# 1799                           NaN                            NaN
# 1800                           NaN                            NaN
# 1801                           NaN                            NaN
# 1802                           NaN                            NaN
# 1803                           NaN                            NaN
# 1804                           NaN                            NaN
# 1805                           NaN                            NaN
# 1806                           NaN                            NaN
# 1807                           9.0                            NaN
# 1808                           NaN                            NaN
# 1809                           9.0                            NaN
# 1810                           NaN                            NaN
# 1811                           NaN                            NaN
# 1812                           NaN                            NaN
# 1813                           NaN                            NaN
# 1814                           NaN                            NaN
# 1815                           NaN                            NaN
# 1816                           NaN                            NaN
# 1817                           NaN                            NaN
# 1818                           NaN                            NaN
# 1819                          38.0                           17.0
#
#       Measles Imported Previous 52 weeks Max   Measles Imported Cum 2019   \
# 0                                         0.0                         NaN
# 1                                         1.0                         NaN
# 2                                         1.0                         NaN
# 3                                         1.0                         NaN
# 4                                         0.0                         NaN
# 5                                        16.0                         NaN
# 6                                         1.0                         NaN
# 7                                         0.0                         NaN
# 8                                         6.0                         NaN
# 9                                         1.0                         NaN
# 10                                        0.0                         NaN
# 11                                        0.0                         NaN
# 12                                        1.0                         NaN
# 13                                        1.0                         NaN
# 14                                        2.0                         NaN
# 15                                        1.0                         NaN
# 16                                        1.0                         NaN
# 17                                        4.0                         NaN
# 18                                        0.0                         NaN
# 19                                        1.0                         NaN
# 20                                        3.0                         NaN
# 21                                        1.0                         NaN
# 22                                        2.0                         NaN
# 23                                        1.0                         NaN
# 24                                        1.0                         NaN
# 25                                        0.0                         NaN
# 26                                        0.0                         NaN
# 27                                        1.0                         NaN
# 28                                        1.0                         NaN
# 29                                        0.0                         NaN
# ...                                       ...                         ...
# 1790                                      1.0                         1.0
# 1791                                      0.0                         NaN
# 1792                                      1.0                         1.0
# 1793                                      1.0                         6.0
# 1794                                      0.0                         NaN
# 1795                                      0.0                         NaN
# 1796                                      1.0                         1.0
# 1797                                      1.0                         5.0
# 1798                                      1.0                         3.0
# 1799                                      1.0                         1.0
# 1800                                      1.0                         1.0
# 1801                                      1.0                         1.0
# 1802                                      0.0                         NaN
# 1803                                      1.0                         NaN
# 1804                                      0.0                         NaN
# 1805                                      0.0                         NaN
# 1806                                      0.0                         NaN
# 1807                                      3.0                        30.0
# 1808                                      0.0                         NaN
# 1809                                      3.0                        27.0
# 1810                                      0.0                         NaN
# 1811                                      3.0                         NaN
# 1812                                      0.0                         NaN
# 1813                                      0.0                         NaN
# 1814                                      0.0                         NaN
# 1815                                      0.0                         NaN
# 1816                                      0.0                         NaN
# 1817                                      0.0                         NaN
# 1818                                      NaN                         NaN
# 1819                                     68.0                       375.0
#
#       Measles Imported Cum 2018
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            1.0
# 4                            NaN
# 5                            1.0
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           1.0
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27                           NaN
# 28                           NaN
# 29                           NaN
# ...                          ...
# 1790                         NaN
# 1791                         NaN
# 1792                         1.0
# 1793                         7.0
# 1794                         1.0
# 1795                         2.0
# 1796                         3.0
# 1797                         1.0
# 1798                         1.0
# 1799                         NaN
# 1800                         NaN
# 1801                         NaN
# 1802                         NaN
# 1803                         1.0
# 1804                         NaN
# 1805                         NaN
# 1806                         NaN
# 1807                         9.0
# 1808                         NaN
# 1809                         8.0
# 1810                         NaN
# 1811                         NaN
# 1812                         NaN
# 1813                         NaN
# 1814                         NaN
# 1815                         NaN
# 1816                         NaN
# 1817                         NaN
# 1818                         NaN
# 1819                        60.0
#
# [1820 rows x 10 columns]

# %%
NNDSS_HALF = NNDSS_df2.loc[NNDSS_df2["MMWR Week"] == 26]
NNDSS_HALF.head()
# Out:
#      Reporting Area  MMWR Week  Measles Indigenous Current week  \
# 1750   US RESIDENTS         26                              NaN
# 1751    NEW ENGLAND         26                              NaN
# 1752    CONNECTICUT         26                              NaN
# 1753          MAINE         26                              NaN
# 1754  MASSACHUSETTS         26                              NaN
#
#       Measles Indigenous Previous 52 weeks Max   Measles Indigenous Cum 2019   \
# 1750                                       60.0                         668.0
# 1751                                        2.0                           3.0
# 1752                                        2.0                           2.0
# 1753                                        1.0                           1.0
# 1754                                        0.0                           NaN
#
#       Measles Indigenous Cum 2018   Measles Imported Current week  \
# 1750                          38.0                           17.0
# 1751                           NaN                            NaN
# 1752                           NaN                            NaN
# 1753                           NaN                            NaN
# 1754                           NaN                            NaN
#
#       Measles Imported Previous 52 weeks Max   Measles Imported Cum 2019   \
# 1750                                     68.0                       375.0
# 1751                                      2.0                         7.0
# 1752                                      1.0                         1.0
# 1753                                      1.0                         1.0
# 1754                                      2.0                         3.0
#
#       Measles Imported Cum 2018
# 1750                        60.0
# 1751                         3.0
# 1752                         3.0
# 1753                         NaN
# 1754                         NaN

# %%
NNDSS_HALF.count()
# Out:
# Reporting Area                               70
# MMWR Week                                    70
# Measles Indigenous Current week               0
# Measles Indigenous Previous 52 weeks Max     69
# Measles Indigenous Cum 2019                  29
# Measles Indigenous Cum 2018                  14
# Measles Imported Current week                 5
# Measles Imported Previous 52 weeks Max       69
# Measles Imported Cum 2019                    36
# Measles Imported Cum 2018                    33
# dtype: int64

# %%
NNDSS_HALF_CLEAN = NNDSS_HALF.drop([1750,1758,1777,1793,1807,1819], axis=0)
NNDSS_HALF_CLEAN.count()
# Out:
# Reporting Area                               64
# MMWR Week                                    64
# Measles Indigenous Current week               0
# Measles Indigenous Previous 52 weeks Max     63
# Measles Indigenous Cum 2019                  23
# Measles Indigenous Cum 2018                   8
# Measles Imported Current week                 2
# Measles Imported Previous 52 weeks Max       63
# Measles Imported Cum 2019                    30
# Measles Imported Cum 2018                    27
# dtype: int64

# %%
NNDSS_HALF_CLEAN.sum()
# Out:
# Reporting Area                               NEW ENGLANDCONNECTICUTMAINEMASSACHUSETTSNEW HA...
# MMWR Week                                                                                 1664
# Measles Indigenous Current week                                                              0
# Measles Indigenous Previous 52 weeks Max                                                   145
# Measles Indigenous Cum 2019                                                                681
# Measles Indigenous Cum 2018                                                                 59
# Measles Imported Current week                                                               17
# Measles Imported Previous 52 weeks Max                                                     150
# Measles Imported Cum 2019                                                                  438
# Measles Imported Cum 2018                                                                   85
# dtype: object

# %%
NNDSS_HALF_CLEAN.head()
# Out:
#      Reporting Area  MMWR Week  Measles Indigenous Current week  \
# 1751    NEW ENGLAND         26                              NaN
# 1752    CONNECTICUT         26                              NaN
# 1753          MAINE         26                              NaN
# 1754  MASSACHUSETTS         26                              NaN
# 1755  NEW HAMPSHIRE         26                              NaN
#
#       Measles Indigenous Previous 52 weeks Max   Measles Indigenous Cum 2019   \
# 1751                                        2.0                           3.0
# 1752                                        2.0                           2.0
# 1753                                        1.0                           1.0
# 1754                                        0.0                           NaN
# 1755                                        0.0                           NaN
#
#       Measles Indigenous Cum 2018   Measles Imported Current week  \
# 1751                           NaN                            NaN
# 1752                           NaN                            NaN
# 1753                           NaN                            NaN
# 1754                           NaN                            NaN
# 1755                           NaN                            NaN
#
#       Measles Imported Previous 52 weeks Max   Measles Imported Cum 2019   \
# 1751                                      2.0                         7.0
# 1752                                      1.0                         1.0
# 1753                                      1.0                         1.0
# 1754                                      2.0                         3.0
# 1755                                      1.0                         2.0
#
#       Measles Imported Cum 2018
# 1751                         3.0
# 1752                         3.0
# 1753                         NaN
# 1754                         NaN
# 1755                         NaN

# %%
NNDSS_HALF_CLEAN.to_csv("measles_summary.csv", header = True, index = False)
NNDSS_HALF_CLEAN.head()
# Out:
#      Reporting Area  MMWR Week  Measles Indigenous Current week  \
# 1751    NEW ENGLAND         26                              NaN
# 1752    CONNECTICUT         26                              NaN
# 1753          MAINE         26                              NaN
# 1754  MASSACHUSETTS         26                              NaN
# 1755  NEW HAMPSHIRE         26                              NaN
#
#       Measles Indigenous Previous 52 weeks Max   Measles Indigenous Cum 2019   \
# 1751                                        2.0                           3.0
# 1752                                        2.0                           2.0
# 1753                                        1.0                           1.0
# 1754                                        0.0                           NaN
# 1755                                        0.0                           NaN
#
#       Measles Indigenous Cum 2018   Measles Imported Current week  \
# 1751                           NaN                            NaN
# 1752                           NaN                            NaN
# 1753                           NaN                            NaN
# 1754                           NaN                            NaN
# 1755                           NaN                            NaN
#
#       Measles Imported Previous 52 weeks Max   Measles Imported Cum 2019   \
# 1751                                      2.0                         7.0
# 1752                                      1.0                         1.0
# 1753                                      1.0                         1.0
# 1754                                      2.0                         3.0
# 1755                                      1.0                         2.0
#
#       Measles Imported Cum 2018
# 1751                         3.0
# 1752                         3.0
# 1753                         NaN
# 1754                         NaN
# 1755                         NaN

# %%
measles_summary_df = pd.read_csv("measles_summarized.csv")

# %%
measles_summary_df
# Out:
#                      Disease  2018  2019
# 0                NEW ENGLAND     6    10
# 1                CONNECTICUT     5     3
# 2                      MAINE     2     2
# 3              MASSACHUSETTS     2     3
# 4              NEW HAMPSHIRE     1     2
# 5               RHODE ISLAND     0     0
# 6                    VERMONT     1     0
# 7                 NEW JERSEY    15    14
# 8                   NEW YORK    60   206
# 9              NEW YORK CITY    51   544
# 10              PENNSYLVANIA     7     9
# 11        EAST NORTH CENTRAL    23    53
# 12                  ILLINOIS     5     9
# 13                   INDIANA     2     1
# 14                  MICHIGAN    18    43
# 15                      OHIO     0     0
# 16                 WISCONSIN     0     0
# 17        WEST NORTH CENTRAL    36     2
# 18                      IOWA     0     0
# 19                    KANSAS    21     0
# 20                 MINNESOTA     1     0
# 21                  MISSOURI    15     2
# 22                  NEBRASKA     0     0
# 23              NORTH DAKOTA     0     0
# 24              SOUTH DAKOTA     0     0
# 25                  DELAWARE     0     0
# 26                    OREGON     5    14
# 27      DISTRICT OF COLUMBIA     1     0
# 28                   FLORIDA     5     3
# 29                   GEORGIA     2     4
# ..                       ...   ...   ...
# 35        EAST SOUTH CENTRAL     3     7
# 36                   ALABAMA     0     0
# 37                  KENTUCKY     2     2
# 38               MISSISSIPPI     0     0
# 39                 TENNESSEE     3     5
# 40                  ARKANSAS     1     0
# 41                 LOUISIANA     2     0
# 42                  OKLAHOMA     5     4
# 43                     TEXAS    11    15
# 44                  MOUNTAIN     3     4
# 45                   ARIZONA     1     1
# 46                  COLORADO     1     1
# 47                     IDAHO     1     1
# 48                   MONTANA     0     0
# 49                    NEVADA     2     0
# 50                NEW MEXICO     1     1
# 51                      UTAH     0     0
# 52                   WYOMING     0     0
# 53                    ALASKA     0     0
# 54                CALIFORNIA    26    55
# 55                    HAWAII     0     0
# 56                WASHINGTON    15    76
# 57            US TERRITORIES     0     0
# 58            AMERICAN SAMOA     0     0
# 59  NORTHERN MARIANA ISLANDS     0     0
# 60                      GUAM     0     0
# 61               PUERTO RICO     0     0
# 62       U.S. VIRGIN ISLANDS     0     0
# 63          NON-US RESIDENTS     0     0
# 64                   Measles   368  1102
#
# [65 rows x 3 columns]

# %%
measles_total = measles_summary_df.drop(measles_summary_df.index[0:64])

# %%
measles_total
# Out:
#     Disease  2018  2019
# 64  Measles   368  1102

# %%
measles_total = measles_total.reset_index(drop=True)
measles_total
# Out:
#    Disease  2018  2019
# 0  Measles   368  1102

# %%
#combined measles
combined_measles = pd.merge(cdc_shorter_three, measles_total, how="outer", on="Disease")
combined_measles.head()
# Out:
#     2013   2014   2015  2016 2017  Disease  2018  2019
# 0  187.0  667.0  188.0  85.0  122  Measles   368  1102

# %%
complete_measles = combined_measles.drop(combined_measles.columns[5], axis=1)
complete_measles
# Out:
#     2013   2014   2015  2016 2017  2018  2019
# 0  187.0  667.0  188.0  85.0  122   368  1102

# %%
years = complete_measles.keys()
years
# Out:
# Index(['2013', '2014', '2015', '2016', '2017', '2018', '2019'], dtype='object')

# %%
cases = complete_measles.iloc[0]
cases
# Out:
# 2013     187
# 2014     667
# 2015     188
# 2016      85
# 2017     122
# 2018     368
# 2019    1102
# Name: 0, dtype: object

# %%
measles_plot, = plt.plot(years, cases, color="green")
plt.title("Reported Cases of Measles in the U.S.")
plt.xlabel("years")
plt.ylabel("Reported Cases")
# Out:
# Text(0, 0.5, 'Reported Cases')

# %%
x_axis = np.arange(len(years))
x_axis
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
measles_bar = complete_measles.transpose()
measles_bar
# Out:
#          0
# 2013   187
# 2014   667
# 2015   188
# 2016    85
# 2017   122
# 2018   368
# 2019  1102

# %%
values = measles_bar.loc[0]
values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-205-c4eb6b71d488> in <module>
# ----> 1 values = measles_bar.loc[0]
#       2 values.head()
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1910
#    1911         # fall thru to straight lookup
# -> 1912         self._validate_key(key, axis)
#    1913         return self._get_label(key, axis=axis)
#    1914
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1797
#    1798         if not is_list_like_indexer(key):
# -> 1799             self._convert_scalar_indexer(key, axis)
#    1800
#    1801     def _is_scalar_access(self, key):
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_scalar_indexer(self, key, axis)
#     260         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     261         # a scalar
# --> 262         return ax._convert_scalar_indexer(key, kind=self.name)
#     263
#     264     def _convert_slice_indexer(self, key, axis):
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in _convert_scalar_indexer(self, key, kind)
#    2879             elif kind in ['loc'] and is_integer(key):
#    2880                 if not self.holds_integer():
# -> 2881                     return self._invalid_indexer('label', key)
#    2882
#    2883         return key
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in _invalid_indexer(self, form, key)
#    3065                         "indexers [{key}] of {kind}".format(
#    3066                             form=form, klass=type(self), key=key,
# -> 3067                             kind=type(key)))
#    3068
#    3069     # --------------------------------------------------------------------
#
# TypeError: cannot do label indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [0] of <class 'int'>

# %%
plt.bar(years, measles_bar.loc[0], color='r', alpha=0.5, align="center")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-200-f743cc34d15d> in <module>
# ----> 1 plt.bar(years, measles_bar.loc[0], color='r', alpha=0.5, align="center")
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1910
#    1911         # fall thru to straight lookup
# -> 1912         self._validate_key(key, axis)
#    1913         return self._get_label(key, axis=axis)
#    1914
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1797
#    1798         if not is_list_like_indexer(key):
# -> 1799             self._convert_scalar_indexer(key, axis)
#    1800
#    1801     def _is_scalar_access(self, key):
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_scalar_indexer(self, key, axis)
#     260         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     261         # a scalar
# --> 262         return ax._convert_scalar_indexer(key, kind=self.name)
#     263
#     264     def _convert_slice_indexer(self, key, axis):
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in _convert_scalar_indexer(self, key, kind)
#    2879             elif kind in ['loc'] and is_integer(key):
#    2880                 if not self.holds_integer():
# -> 2881                     return self._invalid_indexer('label', key)
#    2882
#    2883         return key
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in _invalid_indexer(self, form, key)
#    3065                         "indexers [{key}] of {kind}".format(
#    3066                             form=form, klass=type(self), key=key,
# -> 3067                             kind=type(key)))
#    3068
#    3069     # --------------------------------------------------------------------
#
# TypeError: cannot do label indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [0] of <class 'int'>

# %%
#measles_summary_df = measles_summary_df.drop(measles_summary_df.columns[[1,2,4,5,6,7,8,9]], axis=1)
#measles_summary_df

# %%
#MMAX = NNDSS_HALF_CLEAN["Measles Indigenous Previous 52 weeks Max"]

# %%
#NNDSS_HALF_CLEAN = NNDSS_HALF_CLEAN.rename(index=str, columns=
                                             {"Measles Indigenous Current week" : "MIDCW",
                                              "Measles Indigenous Previous 52 weeks Max" : "MIDMAX",
                                              "Measles Indigenous Cum 2019" : "MID 2019"
}
)
# Out:
#   File "<ipython-input-66-42448fa14d99>", line 2
#     {"Measles Indigenous Current week" : "MIDCW",
#     ^
# IndentationError: unexpected indent

# %%
#NNDSS_HALF_CLEAN.head()

# %%
#NNDSS_HALF_CLEAN['Measles Indigenous Previous 52 weeks Max']

# %%
#NNDSS_HALF_CLEAN['2019'] = NNDSS_HALF_CLEAN['Measles , Idigenousis, Cum 2019'] + NNDSS_HALF_CLEAN['Measles , Imported, Cum 2019'] - NNDSS_HALF_CLEAN['Measles , Imported, Current week']
