# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pprint import pprint

# %%
history_df = pd.read_csv("MeaslesCases_1928_2002 Total USA.csv")
history_df.count()
# Out:
# Year     75
# Cases    75
# dtype: int64

# %%
history_df.head()
# Out:
#    Year   Cases
# 0  1928  483337
# 1  1929  339061
# 2  1930  384597
# 3  1931  438435
# 4  1932  390114

# %%
hist_df = history_df['Cases']
hist_df.plot()
plt.title('Historical levels of Measles in the U.S.', color ="black", size=15)
plt.xlabel("Decades", size= 15)
plt.ylabel("Reported Cases", size=15)
plt.savefig("historical.png", bbox_inches='tight')
plt.show()
